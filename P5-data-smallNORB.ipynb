# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from smallnorb.dataset import SmallNORBDataset

dataset = SmallNORBDataset(dataset_root='/mnt/datasets/smallnorb/')

# # Dump all images to disk
# dataset.export_to_jpg(export_dir='smallnorb_export')

# # Explore random examples of the training set
# # to show how data look like
# dataset.explore_random_examples(dataset_split='train')
# Out:
# Loading images...: 100%|██████████| 48600/48600 [00:19<00:00, 2505.51it/s]
# Loading categories...: 100%|██████████| 24300/24300 [00:00<00:00, 2206572.57it/s]
# Loading info...: 100%|██████████| 24300/24300 [00:00<00:00, 649649.67it/s]
# Loading images...: 100%|██████████| 48600/48600 [00:19<00:00, 2494.38it/s]
# Loading categories...: 100%|██████████| 24300/24300 [00:00<00:00, 2107036.86it/s]
# Loading info...: 100%|██████████| 24300/24300 [00:00<00:00, 641565.03it/s]

# %%
dataset_train = dataset.data['train']

# %%
subplots = plt.subplots(nrows=1, ncols=2)
dataset_train[1].show(subplots)
