# %%
import os, sys
import numpy as np
import pickle

with open('metrics2.2.dump', 'rb') as f:
    (loss, acc, vacc) = pickle.load(f)

with open('weights2.2.dump', 'rb') as f:
    (W_conv, W_fc, W_out) = pickle.load(f)

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

epochs = len(loss)

# %%
plt.plot(list(range(epochs)), loss, label='loss')
plt.legend()

# %%
plt.plot(list(range(epochs)), acc, label='acc')
plt.plot(list(range(epochs)), vacc, label='vacc')
plt.legend()

# %%
for padded_filter in W_conv:
    conv_filter = padded_filter[:-1].reshape(7,7+21)[:,:7]
#     convmat = np.block([
#             #                 vvv throw away final padding & bias
#             [np.zeros(jj), padded_filter[:-22], np.zeros(21-jj)] for jj in range(22)
#         ])
#     plt.figure(figsize=(12,12))
    plt.figure(figsize=(2,2))
    plt.imshow(conv_filter)
